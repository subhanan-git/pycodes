# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import statsmodels.api as sm

# %%
file_path ='C:\\Users\\rohns\\OneDrive\\Desktop\\Sem 3 Term Paper\\Final Data.xlsx'
data= pd.read_excel(file_path)

# %%
data.head(5)
# Out:
#    Salaries and Wages  Interest Expense  Corporate Tax  Profit After Tax  \
# 0               104.3             178.5           24.6              49.3
# 1                77.1              75.9           32.1              87.9
# 2               213.4              79.9           57.0              83.1
# 3               163.7             671.4          132.9             222.5
# 4                19.5             334.5            3.7              12.9
#
#    Total Asset  Gross Intangible Asset  Net Sales  Average Total Asset  \
# 0       3021.0                     1.7     1253.1              2768.10
# 1       3542.3                     3.2      430.8              3486.75
# 2       3009.7                     2.0      997.1              3001.65
# 3      10014.5                   174.6     4273.0              9252.00
# 4       4188.3                     1.9      620.7              4032.85
#
#       Size  Debt to Equity Ratio  Value Added (VA)  Human Capital (HC)  \
# ...

# %%
stats= data.describe()
print(stats)
# Out:
#        Salaries and Wages  Interest Expense  Corporate Tax  Profit After Tax  \
# count          255.000000        255.000000     255.000000        255.000000
# mean           227.447843        678.467059     164.344706        449.824314
# std            475.961567       2130.613432     392.280942       1412.961403
# min              1.000000      -1230.800000       0.100000      -4603.300000
# 25%             33.950000         28.400000       6.250000         12.450000
# 50%             78.900000        123.400000      30.500000         88.100000
# 75%            203.000000        462.950000     117.250000        312.300000
# max           5754.300000      21968.500000    3684.600000      14966.200000
#
#          Total Asset  Gross Intangible Asset     Net Sales  \
# count     255.000000              255.000000    255.000000
# mean    19485.879216              463.911373   3744.660392
# std     41426.563283             2684.957648   6976.998811
# ...

# %%
variables1= data[['VAIC','Return on Asset (ROA)','Asset Turnover Ratio (ATO)','Size', 'Debt to Equity Ratio']]
corr_matrx1=variables1.corr()
print(corr_matrx1)
# Out:
#                                 VAIC  Return on Asset (ROA)  \
# VAIC                        1.000000               0.506987
# Return on Asset (ROA)       0.506987               1.000000
# Asset Turnover Ratio (ATO)  0.009726               0.429832
# Size                       -0.032459              -0.026800
# Debt to Equity Ratio       -0.026040               0.010660
#
#                             Asset Turnover Ratio (ATO)      Size  \
# VAIC                                          0.009726 -0.032459
# Return on Asset (ROA)                         0.429832 -0.026800
# Asset Turnover Ratio (ATO)                    1.000000 -0.037681
# Size                                         -0.037681  1.000000
# Debt to Equity Ratio                         -0.045895 -0.011778
#
#                             Debt to Equity Ratio
# VAIC                                   -0.026040
# Return on Asset (ROA)                   0.010660
# Asset Turnover Ratio (ATO)             -0.045895
# ...

# %%
variables2= data[['Human Capital Efficiency (HCE)', 'Structural Capital Efficiency (SCE)', 'Capital Employed Efficiency (CEE)','Return on Asset (ROA)','Asset Turnover Ratio (ATO)','Size','Debt to Equity Ratio']]
corr_matrx2= variables2.corr()
print(corr_matrx2)
# Out:
#                                      Human Capital Efficiency (HCE)  \
# Human Capital Efficiency (HCE)                             1.000000
# Structural Capital Efficiency (SCE)                        0.230725
# Capital Employed Efficiency (CEE)                          0.423268
# Return on Asset (ROA)                                      0.499836
# Asset Turnover Ratio (ATO)                                 0.008600
# Size                                                      -0.034062
# Debt to Equity Ratio                                      -0.024613
#
#                                      Structural Capital Efficiency (SCE)  \
# Human Capital Efficiency (HCE)                                  0.230725
# Structural Capital Efficiency (SCE)                             1.000000
# Capital Employed Efficiency (CEE)                               0.108871
# Return on Asset (ROA)                                           0.156922
# ...

# %%
y = data['Return on Asset (ROA)']
x = data[['VAIC', 'Debt to Equity Ratio', 'Size']] 
x = sm.add_constant(x)
model = sm.OLS(y, x)
results = model.fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Return on Asset (ROA)   R-squared:                       0.258
# Model:                               OLS   Adj. R-squared:                  0.249
# Method:                    Least Squares   F-statistic:                     29.05
# Date:                   Sat, 28 Oct 2023   Prob (F-statistic):           3.72e-16
# Time:                           16:54:06   Log-Likelihood:                 361.36
# No. Observations:                    255   AIC:                            -714.7
# Df Residuals:                        251   BIC:                            -700.6
# Df Model:                              3
# Covariance Type:               nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
y = data['Return on Asset (ROA)']
x1 = data[['Human Capital Efficiency (HCE)','Structural Capital Efficiency (SCE)','Capital Employed Efficiency (CEE)','Debt to Equity Ratio', 'Size']]
x1 = sm.add_constant(x1)
model = sm.OLS(y, x1)
results = model.fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Return on Asset (ROA)   R-squared:                       0.855
# Model:                               OLS   Adj. R-squared:                  0.852
# Method:                    Least Squares   F-statistic:                     293.3
# Date:                   Sat, 28 Oct 2023   Prob (F-statistic):          3.72e-102
# Time:                           16:56:33   Log-Likelihood:                 569.44
# No. Observations:                    255   AIC:                            -1127.
# Df Residuals:                        249   BIC:                            -1106.
# Df Model:                              5
# Covariance Type:               nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
y1= data['Asset Turnover Ratio (ATO)']
x2= data[['VAIC', 'Return on Asset (ROA)', 'Debt to Equity Ratio', 'Size']]
x2 = sm.add_constant(x2)
model = sm.OLS(y1, x2)
results = model.fit()
print(results.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Asset Turnover Ratio (ATO)   R-squared:                       0.248
# Model:                                    OLS   Adj. R-squared:                  0.236
# Method:                         Least Squares   F-statistic:                     20.57
# Date:                        Sat, 28 Oct 2023   Prob (F-statistic):           1.14e-14
# Time:                                17:05:57   Log-Likelihood:                -49.938
# No. Observations:                         255   AIC:                             109.9
# Df Residuals:                             250   BIC:                             127.6
# Df Model:                                   4
# Covariance Type:                    nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
y1= data['Asset Turnover Ratio (ATO)']
x3= data[['Human Capital Efficiency (HCE)','Structural Capital Efficiency (SCE)','Capital Employed Efficiency (CEE)', 'Return on Asset (ROA)', 'Debt to Equity Ratio', 'Size']]
x3 = sm.add_constant(x3)
model = sm.OLS(y1, x3)
results = model.fit()
print(results.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Asset Turnover Ratio (ATO)   R-squared:                       0.398
# Model:                                    OLS   Adj. R-squared:                  0.384
# Method:                         Least Squares   F-statistic:                     27.36
# Date:                        Sat, 28 Oct 2023   Prob (F-statistic):           5.68e-25
# Time:                                17:06:55   Log-Likelihood:                -21.459
# No. Observations:                         255   AIC:                             56.92
# Df Residuals:                             248   BIC:                             81.71
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
data1= pd.read_excel('C:\\Users\\rohns\\OneDrive\\Desktop\\Sem 3 Term Paper\\Panel Data.xlsx')
data1.head(5)
# Out:
#              Companies  Year  Salaries & wages  Interest expense  \
# 0  A G 8 Ventures Ltd.  2015             104.3             178.5
# 1  A G 8 Ventures Ltd.  2016              88.6             198.7
# 2  A G 8 Ventures Ltd.  2017              71.1             201.9
# 3  A G 8 Ventures Ltd.  2018              58.6             193.0
# 4     A G I Infra Ltd.  2018              70.9              76.3
#
#    Corporate tax  Profit after tax  Total Assets  Gross Intangible Assets  \
# 0           24.6              49.3        3021.0                      1.7
# 1           15.9              15.1        3055.7                     38.2
# 2            9.6              29.5        3135.7                     38.2
# 3            2.2             -74.3        2984.2                     38.2
# 4           37.5             116.5        1911.5                      0.2
#
#    Net Sales  Average Total Asset  ...  Value Added (VA)  Human Capital (HC)  \
# ...

# %%
panel_data = data1.set_index(['Companies', 'Year'])

# %%
panel_data.sort_index(inplace=True)

# %%
if "Debt to Equity Ratio" in data1.columns:
    print("The column 'Certain_Variable' exists in the DataFrame.")
else:
    print("The column 'Certain_Variable' does not exist in the DataFrame.")
# Out:
# The column 'Certain_Variable' exists in the DataFrame.

# %%
model1 = sm.OLS(panel_data['Return on Asset (ROA)'], sm.add_constant(panel_data[['VAIC', 'Size', 'Debt to Equity Ratio']])).fit()

# %%
print(panel_data.head())
# Out:
#                           Salaries & wages  Interest expense  Corporate tax  \
# Companies           Year
# A G 8 Ventures Ltd. 2015             104.3             178.5           24.6
#                     2016              88.6             198.7           15.9
#                     2017              71.1             201.9            9.6
#                     2018              58.6             193.0            2.2
# A G I Infra Ltd.    2018              70.9              76.3           37.5
#
#                           Profit after tax  Total assets  \
# Companies           Year
# A G 8 Ventures Ltd. 2015              49.3        3021.0
#                     2016              15.1        3055.7
#                     2017              29.5        3135.7
#                     2018             -74.3        2984.2
# A G I Infra Ltd.    2018             116.5        1911.5
#
#                           Gross intangible assets  Net sales  \
# Companies           Year
# ...

# %%
print(model1.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Return on Asset (ROA)   R-squared:                       0.253
# Model:                               OLS   Adj. R-squared:                  0.245
# Method:                    Least Squares   F-statistic:                     29.93
# Date:                   Sat, 28 Oct 2023   Prob (F-statistic):           1.08e-16
# Time:                           20:15:26   Log-Likelihood:                 391.32
# No. Observations:                    269   AIC:                            -774.6
# Df Residuals:                        265   BIC:                            -760.3
# Df Model:                              3
# Covariance Type:               nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
model2 = sm.OLS(panel_data['Return on Asset (ROA)'], sm.add_constant(panel_data[['Human Capital Efficiency (HCE)','Structural Capital Efficiency (SCE)','Capital Employed Efficiency (CEE)', 'Size', 'Debt to Equity Ratio']])).fit()
print(model2.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Return on Asset (ROA)   R-squared:                       0.896
# Model:                               OLS   Adj. R-squared:                  0.894
# Method:                    Least Squares   F-statistic:                     452.0
# Date:                   Sat, 28 Oct 2023   Prob (F-statistic):          7.22e-127
# Time:                           20:32:15   Log-Likelihood:                 656.20
# No. Observations:                    269   AIC:                            -1300.
# Df Residuals:                        263   BIC:                            -1279.
# Df Model:                              5
# Covariance Type:               nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
model3 = sm.OLS(panel_data['Asset Turnover Ratio (ATO)'], sm.add_constant(panel_data[['VAIC','Return on Asset (ROA)','Size', 'Debt to Equity Ratio']])).fit()
print(model3.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Asset Turnover Ratio (ATO)   R-squared:                       0.299
# Model:                                    OLS   Adj. R-squared:                  0.289
# Method:                         Least Squares   F-statistic:                     28.18
# Date:                        Sat, 28 Oct 2023   Prob (F-statistic):           1.67e-19
# Time:                                20:34:47   Log-Likelihood:                -21.711
# No. Observations:                         269   AIC:                             53.42
# Df Residuals:                             264   BIC:                             71.40
# Df Model:                                   4
# Covariance Type:                    nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
model4 = sm.OLS(panel_data['Asset Turnover Ratio (ATO)'], sm.add_constant(panel_data[['Return on Asset (ROA)', 'Human Capital Efficiency (HCE)','Structural Capital Efficiency (SCE)','Capital Employed Efficiency (CEE)', 'Size', 'Debt to Equity Ratio']])).fit()
print(model4.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Asset Turnover Ratio (ATO)   R-squared:                       0.339
# Model:                                    OLS   Adj. R-squared:                  0.324
# Method:                         Least Squares   F-statistic:                     22.36
# Date:                        Sat, 28 Oct 2023   Prob (F-statistic):           3.09e-21
# Time:                                20:35:46   Log-Likelihood:                -13.919
# No. Observations:                         269   AIC:                             41.84
# Df Residuals:                             262   BIC:                             67.00
# Df Model:                                   6
# Covariance Type:                    nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...
